# %%
import math #用于数学运算
import numpy as np #numpy库，用于科学计算
import tensorflow as tf #tensorflow库 
import h5py #用于读写数据
import matplotlib.pyplot as plt  #matlab绘图
import matplotlib.image as mping #图像显示
from tensorflow.python.framework import ops 

from tensorflow import keras
#coding=utf-8
import os  #打开文件时需要
from PIL import Image
import re
import random
import wtfcv
import cv2

np.random.seed(1)

# %%
dim = 10
def plot_image(i, predictions_array, img):
  predictions_array, img = predictions_array, img[i].reshape(64, 64, 3)
  plt.grid(False)
  plt.xticks([])
  plt.yticks([])

  plt.imshow(img, cmap=plt.cm.binary)


def plot_value_array(i, predictions_array):
  predictions_array = predictions_array
  plt.grid(False)
  plt.xticks(range(dim))
  plt.yticks([])
  thisplot = plt.bar(range(dim), predictions_array, color="#777777")
  plt.ylim([0, 1])
  predicted_label = np.argmax(predictions_array)


def max_index(x):
    max = 0;
    jb = -1;
    for i in range(dim):
        if x[i] > max:
            jb = i
            max = x[i]
    return jb

# %%
out_list = []
out_label = []
for xxx in range(dim):
    dir_path = './real_hondo_train_image/' + str(xxx) +'/'
    ignore_list = ['.DS_Store']
    image_list=os.listdir(dir_path)   
    for pic in image_list:
        if pic in ignore_list:
            continue
        path = dir_path + pic
        im = Image.open(path)
        im = np.asarray(im) #转成矩阵
        im = im/255
        out_list.append(im)
        out_label.append(xxx)

# %%
index = 2345
plt.imshow(out_list[index])
print(out_label[index])
print(out_list[index].shape)
# Out:
# 7
# (64, 64, 3)

# %%
qiege1 = 2500
qiege2 = 2000
    



#打乱顺序
cc = list(zip(out_list, out_label))
random.shuffle(cc)
out_list[:], out_label[:] = zip(*cc)

#分割 
train_x_list = out_list[:qiege1]
test_x_list = out_list[qiege1:]
train_y_list = out_label[:qiege1]
test_y_list = out_label[qiege1:]

#分割出测试集
train_x = np.asarray(train_x_list)
test_x = np.asarray(test_x_list)
train_y = np.asarray(train_y_list)
test_y = np.asarray(test_y_list)


train_x_par = train_x[:qiege2]
train_x_val = train_x[qiege2:]
train_y_par = train_y[:qiege2]
train_y_val = train_y[qiege2:]

# %%
index = 129
plt.imshow(train_x[index])
print(train_y[index])
print(train_x.shape)
print(train_y[index].shape)
# Out:
# 6
# (2500, 64, 64, 3)
# ()

# %%
model = keras.Sequential([
    keras.layers.Conv2D(16, (3, 3), activation='relu', input_shape=(64, 64, 3)),
    keras.layers.MaxPooling2D((2, 2)),
    keras.layers.Conv2D(32, (3, 3), activation='relu'),
    keras.layers.MaxPooling2D((2, 2)),
    keras.layers.Conv2D(32, (3, 3), activation='relu'),
    keras.layers.Flatten(),
    keras.layers.Dropout(0.5),
    keras.layers.Dense(32, activation = 'relu',bias_regularizer=keras.regularizers.l2(0.01)),
    keras.layers.Dense(dim, activation = 'softmax',bias_regularizer=keras.regularizers.l2(0.01))
    
])
model.summary()
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics = ['accuracy'])
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_6 (Conv2D)            (None, 62, 62, 16)        448
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 31, 31, 16)        0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 29, 29, 32)        4640
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 14, 14, 32)        0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 12, 12, 32)        9248
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 4608)              0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 4608)              0
# _________________________________________________________________
# dense_4 (Dense)              (None, 32)                147488
# _________________________________________________________________
# dense_5 (Dense)              (None, 10)                330
# =================================================================
# Total params: 162,154
# Trainable params: 162,154
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(train_x_par, train_y_par, epochs = 25,batch_size = 32 ,validation_data=(train_x_val, train_y_val), verbose = 1)
# Out:
# Train on 2000 samples, validate on 500 samples
# Epoch 1/25
# 2000/2000 [==============================] - 8s 4ms/sample - loss: 1.5808 - accuracy: 0.4500 - val_loss: 0.8064 - val_accuracy: 0.7540
# Epoch 2/25
# 2000/2000 [==============================] - 6s 3ms/sample - loss: 0.6298 - accuracy: 0.7900 - val_loss: 0.4435 - val_accuracy: 0.8540
# Epoch 3/25
# 2000/2000 [==============================] - 6s 3ms/sample - loss: 0.3504 - accuracy: 0.8920 - val_loss: 0.2786 - val_accuracy: 0.9100
# Epoch 4/25
# 2000/2000 [==============================] - 6s 3ms/sample - loss: 0.2308 - accuracy: 0.9305 - val_loss: 0.1982 - val_accuracy: 0.9320
# Epoch 5/25
# 2000/2000 [==============================] - 6s 3ms/sample - loss: 0.1611 - accuracy: 0.9450 - val_loss: 0.2517 - val_accuracy: 0.9160
# Epoch 6/25
# 2000/2000 [==============================] - 6s 3ms/sample - loss: 0.1297 - accuracy: 0.9575 - val_loss: 0.1606 - val_accuracy: 0.9480
# Epoch 7/25
# 2000/2000 [==============================] - 6s 3ms/sample - loss: 0.0866 - accuracy: 0.9730 - val_loss: 0.1193 - val_accuracy: 0.9620
# Epoch 8/25
# 2000/2000 [==============================] - 6s 3ms/sample - loss: 0.0835 - accuracy: 0.9725 - val_loss: 0.1066 - val_accuracy: 0.9600
# Epoch 9/25
# 2000/2000 [==============================] - 7s 3ms/sample - loss: 0.0670 - accuracy: 0.9780 - val_loss: 0.1194 - val_accuracy: 0.9640
# Epoch 10/25
# 2000/2000 [==============================] - 8s 4ms/sample - loss: 0.0531 - accuracy: 0.9820 - val_loss: 0.1162 - val_accuracy: 0.9640
# Epoch 11/25
# 2000/2000 [==============================] - 7s 4ms/sample - loss: 0.0434 - accuracy: 0.9855 - val_loss: 0.1077 - val_accuracy: 0.9700
# Epoch 12/25
# 2000/2000 [==============================] - 7s 3ms/sample - loss: 0.0350 - accuracy: 0.9900 - val_loss: 0.0737 - val_accuracy: 0.9780
# Epoch 13/25
# 2000/2000 [==============================] - 7s 3ms/sample - loss: 0.0356 - accuracy: 0.9890 - val_loss: 0.0799 - val_accuracy: 0.9800
# Epoch 14/25
# 2000/2000 [==============================] - 7s 4ms/sample - loss: 0.0309 - accuracy: 0.9885 - val_loss: 0.0940 - val_accuracy: 0.9700
# Epoch 15/25
# 2000/2000 [==============================] - 7s 4ms/sample - loss: 0.0169 - accuracy: 0.9965 - val_loss: 0.0761 - val_accuracy: 0.9800
# Epoch 16/25
# 2000/2000 [==============================] - 7s 3ms/sample - loss: 0.0346 - accuracy: 0.9910 - val_loss: 0.0890 - val_accuracy: 0.9760
# Epoch 17/25
# 2000/2000 [==============================] - 7s 3ms/sample - loss: 0.0182 - accuracy: 0.9955 - val_loss: 0.0899 - val_accuracy: 0.9800
# Epoch 18/25
# 2000/2000 [==============================] - 6s 3ms/sample - loss: 0.0131 - accuracy: 0.9960 - val_loss: 0.0907 - val_accuracy: 0.9760
# Epoch 19/25
# 2000/2000 [==============================] - 6s 3ms/sample - loss: 0.0171 - accuracy: 0.9925 - val_loss: 0.0751 - val_accuracy: 0.9860
# Epoch 20/25
# 2000/2000 [==============================] - 6s 3ms/sample - loss: 0.0126 - accuracy: 0.9965 - val_loss: 0.0854 - val_accuracy: 0.9840
# Epoch 21/25
# 2000/2000 [==============================] - 6s 3ms/sample - loss: 0.0296 - accuracy: 0.9900 - val_loss: 0.1415 - val_accuracy: 0.9660
# Epoch 22/25
# 2000/2000 [==============================] - 6s 3ms/sample - loss: 0.0353 - accuracy: 0.9855 - val_loss: 0.1422 - val_accuracy: 0.9740
# Epoch 23/25
# 2000/2000 [==============================] - 6s 3ms/sample - loss: 0.0275 - accuracy: 0.9910 - val_loss: 0.0825 - val_accuracy: 0.9800
# Epoch 24/25
# 2000/2000 [==============================] - 9s 5ms/sample - loss: 0.0179 - accuracy: 0.9950 - val_loss: 0.0903 - val_accuracy: 0.9780
# Epoch 25/25
# 2000/2000 [==============================] - 8s 4ms/sample - loss: 0.0106 - accuracy: 0.9970 - val_loss: 0.0784 - val_accuracy: 0.9820

# %%
#测试集上运行模型，获得测试准确度
test_loss, test_acc = model.evaluate(test_x, test_y, verbose = 2)
print("\nTest accuracy", test_acc)
# Out:
# 300/1 - 0s - loss: 0.0975 - accuracy: 0.9667
#
# Test accuracy 0.96666664

# %%
history_dict = model.history.history
acc = history_dict['accuracy']
val_acc = history_dict['val_accuracy']
loss = history_dict['loss']
val_loss = history_dict['val_loss']
epochs = range(1, len(acc) + 1)

# %%
# loss图
# "bo" is for "blue dot"
plt.plot(epochs, loss, 'bo', label='Training loss')
# b is for "solid blue line"
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.show()

# %%
# accu图
plt.clf()   # clear figure
acc_values = history_dict['accuracy']
val_acc_values = history_dict['val_accuracy']

plt.plot(epochs, acc, 'bo', label='Training acc')
plt.plot(epochs, val_acc, 'b', label='Validation acc')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.show()

# %%
# 测试集上预测 查看
prediction = model.predict(test_x)

# %%
index = 279
plt.imshow(test_x[index])
print(test_y[index])
print(prediction[index])
print(max_index(prediction[index]))
# Out:
# 0
# [2.6437315e-01 3.8193353e-05 1.7689250e-04 6.6338559e-03 7.2871441e-01
#  1.9147143e-07 6.2821855e-05 1.5604425e-10 4.5275084e-07 1.0600571e-07]
# 4

# %%
#找出 预测错误的集：
for i in range(test_y.shape[0]):
    if test_y[i] != max_index(prediction[i]):
        print(i, end=", ")
# Out:
# 23, 42, 55, 180, 198, 206, 265, 269, 276, 279,

# %%
num_rows = 33
num_cols = 3
num_images = num_rows*num_cols
plt.figure(figsize=(2*2*num_cols, 2*num_rows))
for i in range(num_images):
  plt.subplot(num_rows, 2*num_cols, 2*i+1)
  plot_image(i, prediction[i], test_x)
  plt.subplot(num_rows, 2*num_cols, 2*i+2)
  plot_value_array(i, prediction[i])
plt.tight_layout()
plt.show()

# %%
model.save("./model/10.h5")
